# %% [markdown]
# # ft_turing - complexity analysis
# ## Complexity theory:
# ### Complexity classes
# ### Asymptotic notation
# ## Implementation method:
# ### Mathematic toolbox:
# #### Regression:
# #### Candidate functions:
# #### How to estimate "distance" between two functions:
# ##### Least squares method:
# ##### Bayesian reggression:

# %% [markdown]
# # ft_turing - complexity analysis
# ## Complexity theory:
# ### Complexity classes
# ### Asymptotic notation
# ## Implementation method:
# ### Mathematic toolbox:
# #### Regression:
# #### Candidate functions:
# #### How to estimate "distance" between two functions:
# ##### Least squares method:
# ##### Bayesian reggression:

# %% [markdown]
# # ft_turing - complexity analysis
# ## Complexity theory:
# ### Complexity classes
# ### Asymptotic notation
# ## Implementation method:
# ### Mathematic toolbox:
# #### Regression:
# #### Candidate functions:
# #### How to estimate "distance" between two functions:
# ##### Least squares method:
# ##### Bayesian reggression:

# %% [markdown]
# # ft_turing - complexity analysis
# ## Complexity theory:
# ### Complexity classes
# ### Asymptotic notation
# ## Implementation method:
# ### Mathematic toolbox:
# #### Regression:
# #### Candidate functions:
# #### How to estimate "distance" between two functions:
# ##### Least squares method:
# ##### Bayesian reggression:

# %% [markdown]
# # ft_turing - complexity analysis
# ## Complexity theory:
# ### Complexity classes
# ### Asymptotic notation
# ## Implementation method:
# ### Mathematic toolbox:
# #### Regression:
# #### Candidate functions:
# #### How to estimate "distance" between two functions:
# ##### Least squares method:
# ##### Bayesian reggression:
